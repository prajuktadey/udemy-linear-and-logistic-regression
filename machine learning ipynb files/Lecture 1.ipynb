# %% [markdown]
# # Basic Jupyter Syntax

# %% [markdown]
# # Heading
# ## Heading 2
# ### Heading 3
# #### Heading 4
#
# * Bullet point 1
#
# This is a MD cell.

# %% [markdown]
# # Arithmetic operators in Python: Python Basics

# %%
#addition of two numbers
2+2
# Out:
# 4

# %%
#subtraction of two numbers
5-3
# Out:
# 2

# %%
#multiplication of two numbers
2*12
# Out:
# 24

# %%
#division of two numbers
5/2
# Out:
# 2.5

# %%
#power or exponetial
5**2 #5 raised to the power of 2
# Out:
# 25

# %%
#modulus or remainder function
5%2
# Out:
# 1

# %%
#multiple operators
5*2+4
# Out:
# 14

# %%
5*(2+4)
# Out:
# 30

# %%
#assign value
var1=4

#display var1
var1
# Out:
# 4

# %%
#update value
var1 = 5*2+4
var1
# Out:
# 14

# %%
#comparison operator
5>2
# Out:
# True

# %%
#comparison operator
3<2
# Out:
# False

# %% [markdown]
# # Strings

# %%
#pass strings in single quotes or double quotes
"Hello World"
# Out:
# 'Hello World'

# %%
#assigning strings to variables
str1 = "Hello World"
str1
#notice the output is coming in single quotation marks
# Out:
# 'Hello World'

# %%
print(str1)
#notice the output is not coming in single quotation marks
# Out:
# Hello World

# %%
#python provides for formatting options with the print function

x = "R" #asigning value
print ("ST {} tutorial".format(x))
# Out:
# ST R tutorial

# %%
#python provides for formatting options with the print function

x = "SQL" #asigning value
print ("ST {} tutorial".format(x))
# Out:
# ST SQL tutorial

# %%
#python provides for formatting options with the print function

x = "R" #asigning value
print ("ST {} tutorial {}".format(x, var1))
# Out:
# ST R tutorial 14

# %%
#length of a string
len(str1)
# Out:
# 11

# %%
#replace function
str1
str1.replace("Hello", "Goodbye") #replace hello with goodbye
# Out:
# 'Goodbye World'

# %%
#indexing starts at 0
str1[6] #position of w is 7
# Out:
# 'W'

# %%
#multiple index
str1[0:6] #all characters from index 0 to 6
# Out:
# 'Hello '

# %%
str1[-2] #from backwards, starting position is -1
# Out:
# 'l'

# %%
#multiple index
str1[0:] #all characters starting from 0
# Out:
# 'Hello World'

# %%
type(str1)
# Out:
# str

# %% [markdown]
# # Lists, Tuples and Directories: Python Basics

# %%
#lists are very similar to strings
#lists can have elements of any type
#in strings, each element was a character

l1 = [1,2,3,4,5]

#check type
type(l1)
# Out:
# list

# %%
#display list
print(l1)
# Out:
# [1, 2, 3, 4, 5]

# %%
l1[0]
# Out:
# 1

# %%
l1[0:3] #first three elements
# Out:
# [1, 2, 3]

# %%
l1[::] #first : for the starting location and second : for the stopping location
# Out:
# [1, 2, 3, 4, 5]

# %%
l1[::2] #step of 2
# Out:
# [1, 3, 5]

# %%
l2= [1, "a", 1.0]
print(l2)
# Out:
# [1, 'a', 1.0]

# %%
type(l2[0])
# Out:
# int

# %%
type(l2[1])
# Out:
# str

# %%
type(l2)
# Out:
# list

# %%
#list inside of a list
l3= [l2, "b", 1.0]
print(l3)
# Out:
# [[1, 'a', 1.0], 'b', 1.0]

# %%
type(l3[0])
# Out:
# list

# %%
l4= [1, 2,3,4,5]
print(l4)
# Out:
# [1, 2, 3, 4, 5]

# %%
l4.remove(l4[3])
print(l4)
# Out:
# [1, 2, 3, 5]

# %%
l4.remove(l4[0])
print(l4)
# Out:
# [2]

# %%
l4=[1, 3, 4, 5]
print(l4)
# Out:
# [1, 3, 4, 5]

# %% [markdown]
# Tuples are immutable and lists are mutable.

# %%
t1= {1,2}
#we cannot change the values of these elements

# %%
print (t1)
# Out:
# {1, 2}

# %%
type(t1)
# Out:
# set

# %% [markdown]
# Dictionary

# %%
#the key1, key2 are just like indexes
d1= {"key1": 1,
     "key2" : 2,
     "key3" : 3}

# %%
d1
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3}

# %%
type(d1)
# Out:
# dict

# %%
d1["key1"]
# Out:
# 1
